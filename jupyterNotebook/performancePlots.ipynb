# %%
import pandas as pd
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
data = pd.read_csv('performanceResults.csv',delimiter=";")
data
# Out:
#    Nodes  Links  Layers  layoutFPS  explorationMinFPS  explorationAvgFPS
# 0    310      0       3         40                 90                 90
# 1    730      0       3         30                 70                 75
# 2   1100      0       3         20                 55                 60
# 3   1560      0       4         20                 40                 55
# 4   2343      0       5         10                 30                 35
# 5    774    387       3         20                 60                 70
# 6    774   1548       3         20                 55                 70
# 7    774   3870       3         10                 40                 60
# 8   1560   3120       4          5                 25                 45
# 9   1020   2040       4         10                 40                 60

# %%
zeroLinks = data[data["Links"]==0] 
zeroLinks
# Out:
#    Nodes  Links  Layers  layoutFPS  explorationMinFPS  explorationAvgFPS
# 0    310      0       3         40                 90                 90
# 1    730      0       3         30                 70                 75
# 2   1100      0       3         20                 55                 60
# 3   1560      0       4         20                 40                 55
# 4   2343      0       5         10                 30                 35

# %%
#import matplotlib.pyplot as plt
#plt.plot(zeroLinks[["explorationAvgFPS","Nodes"]])
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

ax = zeroLinks.plot(x='Nodes', y=['explorationAvgFPS','explorationMinFPS'], marker='.' )
ax.set_xlabel("n Nodes (0 links)")
ax.set_ylabel("FPS")
# Out:
# Text(0, 0.5, 'FPS')

# %%
LinkPerformance = data[data["Nodes"]==774]
LinkPerformance


ax = LinkPerformance.plot(x='Links', y=['explorationAvgFPS','explorationMinFPS'], marker='.')
ax.set_xlabel("n Links (774 nodes)")
ax.set_ylabel("FPS")
# Out:
# Text(0, 0.5, 'FPS')
